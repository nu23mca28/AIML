# %%
import matplotlib.pyplot as plt
X = range(1, 50)
Y = [value*3 for value in X]
plt.plot(X, Y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Draw a line.')
plt.show()

# %%
import matplotlib.pyplot as plt
with open("test.txt") as f:
    data = f.read()
data = data.strip().split('\n')
x=[float(row.split(' ')[0]) for row in data]
y=[float(row.split(' ')[1]) for row in data]
plt.plot(x,y,marker='o', linestyle='-', color='b')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sample graph!')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data.csv', sep=',', parse_dates=True, index_col=0)
df.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
x1 = [10,20,30]
y1 = [20,40,10]
plt.plot(x1, y1, label = "line 1")
x2 = [10,20,30]
y2 = [40,10,30]
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.show()

# %%
import pandas as pd
l=list(map(int,input("Enter the list elements seperated by spaces: ").split()))
ds = pd.Series(l)
print(ds)
# Out:
# Enter the list elements seperated by spaces: 2 4 6 8 10
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
import pandas as pd
ds = pd.Series([2, 4, 6, 8, 10])
print(ds)
print(type(ds))
print(ds.tolist())
print(type(ds.tolist()))
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# <class 'pandas.core.series.Series'>
# [2, 4, 6, 8, 10]
# <class 'list'>

# %%
import pandas as pd
l1=list(map(int,input("Enter the first list elements seperated by spaces: ").split()))
l2=list(map(int,input("Enter the second list elements seperated by spaces: ").split()))
ds1 = pd.Series(l1)
ds2 = pd.Series(l2)
ds = ds1+ds2
print("Add two Series:")
print(ds)
print("Subtract two Series:")
ds = ds1-ds2
print(ds)
print("Multiply two Series:")
ds = ds1*ds2
print(ds)
print("Divide Series1 by Series2:")
ds = ds1/ds2
print(ds)
# Out:
# Enter the first list elements seperated by spaces: 2 4 6 8 10
# Enter the second list elements seperated by spaces: 1 3 5 7 9
# Add two Series:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# Subtract two Series:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
# Multiply two Series:
# 0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64
# Divide Series1 by Series2:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.111111
# dtype: float64

# %%
import pandas as pd
l1=list(map(int,input("Enter the first list elements seperated by spaces: ").split()))
l2=list(map(int,input("Enter the second list elements seperated by spaces: ").split()))
ds1 = pd.Series(l1)
ds2 = pd.Series(l2)
print("Series1:")
print(ds1)
print("Series2:")
print(ds2)
print("Compare the elements of the said Series:")
print("Equals:")
print(ds1 == ds2)
print("Greater than:")
print(ds1 > ds2)
print("Less than:")
print(ds1 < ds2)
# Out:
# Enter the first list elements seperated by spaces: 2 4 6 8 10
# Enter the second list elements seperated by spaces: 1 3 5 7 9
# Series1:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# Series2:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# Compare the elements of the said Series:
# Equals:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Greater than:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool
# Less than:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd
empno = int(input("Enter employee number: "))
ename = input("Enter employee name: ")
basic = float(input("Enter employee basic salary: "))
d1 = {'empno': empno,'ename': ename,'basic': basic}
print("Original dictionary:")
print(d1)
new_series = pd.Series(d1)
print("Converted series:")
print(new_series)
# Out:
# Enter employee number: 028
# Enter employee name: Darshan
# Enter employee basic salary: 5000
# Original dictionary:
# {'empno': 28, 'ename': 'Darshan', 'basic': 5000.0}
# Converted series:
# empno         28
# ename    Darshan
# basic     5000.0
# dtype: object

# %%
import numpy as np
import pandas as pd
l=list(map(int,input("Enter the list elements seperated by spaces: ").split()))
arr = np.array(l)
print("NumPy array:")
print(arr)
new_series = pd.Series(arr)
print("Converted Pandas series:")
print(new_series)
# Out:
# Enter the list elements seperated by spaces: 1 2 3 4 5
# NumPy array:
# [1 2 3 4 5]
# Converted Pandas series:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
Y = np.array([1.5, 3.8, 6.7, 9.0, 11.2, 13.6, 16])

model = LinearRegression()
model.fit(X, Y)

Y_pred = model.predict(X)

mse = mean_squared_error(Y, Y_pred)
r2 = r2_score(Y, Y_pred)

print(f"Coefficient (slope): {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Coefficient (slope): 2.4142857142857133
# Intercept: -0.8285714285714239
# Mean Squared Error: 0.024081632653061246
# R-squared: 0.99896818873402
